# %%
import re
text1='abc123'
text2='456xyz'
text3='a_b c!'
text4='789abcxyz'
text5='abc xyz'
text6='no_digits_here'
print('For text1 \n')

print(re.findall('\d',text1))
print(re.findall('\D',text1))
print(re.findall('\w',text1))
print(re.findall('\W',text1))
print(re.findall('\s',text1))
print(re.findall('\S',text1))
print(re.findall('^abc',text1))
print(re.findall('xyz$',text1))

print('\n For text2 \n')
print(re.findall('\d',text2))
print(re.findall('\D',text2))
print(re.findall('\w',text2))
print(re.findall('\W',text2))
print(re.findall('\s',text2))
print(re.findall('\S',text2))
print(re.findall('^abc',text2))
print(re.findall('xyz$',text2))

print('\n For text3 \n')
print(re.findall('\d',text3))
print(re.findall('\D',text3))
print(re.findall('\w',text3))
print(re.findall('\W',text3))
print(re.findall('\s',text3))
print(re.findall('\S',text3))
print(re.findall('^abc',text3))
print(re.findall('xyz$',text3))

print('\n For text4 \n')
print(re.findall('\d',text4))
print(re.findall('\D',text4))
print(re.findall('\w',text4))
print(re.findall('\W',text4))
print(re.findall('\s',text4))
print(re.findall('\S',text4))
print(re.findall('^abc',text4))
print(re.findall('xyz$',text4))

print('\n For text5 \n')
print(re.findall('\d',text5))
print(re.findall('\D',text5))
print(re.findall('\w',text5))
print(re.findall('\W',text5))
print(re.findall('\s',text5))
print(re.findall('\S',text5))
print(re.findall('^abc',text5))
print(re.findall('xyz$',text5))

print('\n For text6 \n')
print(re.findall('\d',text6))
print(re.findall('\D',text6))
print(re.findall('\w',text6))
print(re.findall('\W',text6))
print(re.findall('\s',text6))
print(re.findall('\S',text6))
print(re.findall('^abc',text6))
print(re.findall('xyz$',text6))
# Out:
# For text1
#
# ['1', '2', '3']
# ['a', 'b', 'c']
# ['a', 'b', 'c', '1', '2', '3']
# []
# []
# ['a', 'b', 'c', '1', '2', '3']
# ['abc']
# []
#
#  For text2
#
# ['4', '5', '6']
# ['x', 'y', 'z']
# ['4', '5', '6', 'x', 'y', 'z']
# []
# []
# ['4', '5', '6', 'x', 'y', 'z']
# []
# ['xyz']
#
#  For text3
#
# []
# ['a', '_', 'b', ' ', 'c', '!']
# ['a', '_', 'b', 'c']
# [' ', '!']
# [' ']
# ['a', '_', 'b', 'c', '!']
# []
# []
#
#  For text4
#
# ['7', '8', '9']
# ['a', 'b', 'c', 'x', 'y', 'z']
# ['7', '8', '9', 'a', 'b', 'c', 'x', 'y', 'z']
# []
# []
# ['7', '8', '9', 'a', 'b', 'c', 'x', 'y', 'z']
# []
# ['xyz']
#
#  For text5
#
# []
# ['a', 'b', 'c', ' ', 'x', 'y', 'z']
# ['a', 'b', 'c', 'x', 'y', 'z']
# [' ']
# [' ']
# ['a', 'b', 'c', 'x', 'y', 'z']
# ['abc']
# ['xyz']
#
#  For text6
#
# []
# ['n', 'o', '_', 'd', 'i', 'g', 'i', 't', 's', '_', 'h', 'e', 'r', 'e']
# ['n', 'o', '_', 'd', 'i', 'g', 'i', 't', 's', '_', 'h', 'e', 'r', 'e']
# []
# []
# ...
