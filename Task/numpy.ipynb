# %%
import numpy as np
arr=np.array([[8,3,7,1],[2,6,4,9],[5,8,1,3]])

print("The sum is: ",np.sum(arr))
print("The mean is: ",np.mean(arr))
print("The min value is: ",np.min(arr))
print("The max value is: ",np.max(arr))
print("The standard deviation is: ",np.std(arr))
# Out:
# The sum is:  57
# The mean is:  4.75
# The min value is:  1
# The max value is:  9
# The standard deviation is:  2.7118566825454966
